# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
mutations_df = pd.read_csv(
    "Dataset/chol_tcga_pan_can_atlas_2018/data_mutations.txt",
    sep="\t",
    header=0
)
mutations_df.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       TRUB1          142940      .     GRCh37         10       116734973
# 1       ASCC1           51008      .     GRCh37         10        73956736
# 2        RRM1            6240      .     GRCh37         11         4148284
# 3     MAP3K11            4296      .     GRCh37         11        65373425
# 4        LMO3           55885      .     GRCh37         12        16757898
#
#    End_Position Strand          Consequence Variant_Classification  ...  \
# 0     116734973      +          stop_gained      Nonsense_Mutation  ...
# 1      73956736      +          stop_gained      Nonsense_Mutation  ...
# 2       4148284      +     missense_variant      Missense_Mutation  ...
# 3      65373425      +     missense_variant      Missense_Mutation  ...
# 4      16757898      +  5_prime_UTR_variant                  5'UTR  ...
#
#   SYMBOL_SOURCE                                             TREMBL TSL  \
# 0          HGNC                          B4DZ90_HUMAN,B3KWQ1_HUMAN   .
# 1          HGNC                                       E9PJM2_HUMAN   .
# 2          HGNC  F5H861_HUMAN,E9PL69_HUMAN,E9PD78_HUMAN,B4DNN4_...   .
# 3          HGNC             E9PLB1_HUMAN,E9PID4_HUMAN,B4DS76_HUMAN   .
# 4          HGNC                                                  .   .
#
#          UNIPARC VARIANT_CLASS  \
# 0  UPI000006DEBE           SNV
# 1  UPI000006F7E9           SNV
# 2  UPI0000000C7C           SNV
# 3  UPI0000049BF7           SNV
# 4  UPI00017A6FD2           SNV
#
#                                          all_effects cDNA_position n_depth  \
# 0    TRUB1,stop_gained,p.Trp295Ter,ENST00000298746,;           946      50
# 1  ASCC1,stop_gained,p.Gln108Ter,ENST00000524829,...           508      71
# 2  RRM1,missense_variant,p.Arg400His,ENST00000423...          1694      50
# 3  MAP3K11,missense_variant,p.Gln577His,ENST00000...          2217      28
# 4  LMO3,5_prime_UTR_variant,,ENST00000261169,;LMO...             .      26
#
#   t_depth Annotation_Status
# 0      58           SUCCESS
# 1      97           SUCCESS
# 2      82           SUCCESS
# 3      59           SUCCESS
# 4      35           SUCCESS
#
# [5 rows x 114 columns]

# %%
print(mutations_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Columns: 114 entries, Hugo_Symbol to Annotation_Status
# dtypes: float64(1), int64(11), object(102)
# memory usage: 3.9+ MB
# None

# %%
print(mutations_df.columns)
# Out:
# Index(['Hugo_Symbol', 'Entrez_Gene_Id', 'Center', 'NCBI_Build', 'Chromosome',
#        'Start_Position', 'End_Position', 'Strand', 'Consequence',
#        'Variant_Classification',
#        ...
#        'SYMBOL_SOURCE', 'TREMBL', 'TSL', 'UNIPARC', 'VARIANT_CLASS',
#        'all_effects', 'cDNA_position', 'n_depth', 't_depth',
#        'Annotation_Status'],
#       dtype='object', length=114)

# %% [markdown]
# ### Transforming data into one line per sample_id and all mutated genes comma-separated in the same line

# %%
mutations_df1 = mutations_df[["Hugo_Symbol", "Tumor_Sample_Barcode"]]

# Group by sample_id and aggregate mutations into a comma-separated string
grouped = mutations_df1.groupby('Tumor_Sample_Barcode')


mutations_df2 = grouped.agg(
    Mutation_Count=('Hugo_Symbol', 'count'),           # Define the name for the mutation count column
    Mutations=('Hugo_Symbol', lambda x: ', '.join(x))  # Define the name for the aggregated mutation column
).reset_index()

mutations_df2.head()
# Out:
#   Tumor_Sample_Barcode  Mutation_Count  \
# 0      TCGA-3X-AAV9-01              75
# 1      TCGA-3X-AAVA-01              60
# 2      TCGA-3X-AAVB-01              48
# 3      TCGA-3X-AAVC-01              84
# 4      TCGA-3X-AAVE-01              68
#
#                                            Mutations
# 0  TRUB1, ASCC1, RRM1, MAP3K11, LMO3, ABCC9, ANKR...
# 1  ASAH2, ROBO4, ARFGAP2, TMEM132C, KRT3, DCLK1, ...
# 2  WDFY4, A1CF, RAN, KRAS, STAT6, TUBGCP3, ISLR2,...
# 3  BEND7, MUC6, ANO3, TSPAN18, UBE2L6, OR9I1, OR1...
# 4  NET1, BIRC2, OR5D16, POC1B, ASB7, EXD1, ALPK3,...

# %%
mutations_df2.to_csv('Dataset/mydata/chol_tcga_pan_can_atlas_2018/mutations_summary.csv', index=False)

# %% [markdown]
# ### Using Gene2Vec-pretrained + GIT-finetuned gene embeddings to get a feature representation of each sample
