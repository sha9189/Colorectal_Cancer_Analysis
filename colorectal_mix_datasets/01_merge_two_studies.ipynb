# %% [markdown]
# ## Realised that there was a typo in the code and in reality the overlapping columns are very less. Hence the datasets cannot be merged. Donot run this notebook.

# %% [markdown]
# # Merge data from studies on
# - Colorectal Adenocarcinoma (TCGA, PanCancer Atlas)
# - Colorectal Adenocarcinoma (TCGA, Firehose Legacy)
#
# 1. Read data from first study and reproduce steps in colorectal_adenocarcinoma/01_colorectal_preliminary.ipynb to have cleaned data.
# 1. Read data from second study and try to match it as much as possible to the data from first study.
# 1. Merge tables.
# 1. Reproduce results with new formed datasets.

# %%
import os
os.chdir("..")

# %%
import pandas as pd
import matplotlib.pyplot as plt
from helpers import load_config, plot_predicted_vs_actual
from colorectal_adenocarcinoma.data_preprocessor import preprocess_data, show_unique_vals_by_column
import sys
import os
import warnings
import copy
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from  colorectal_adenocarcinoma.model_evaluators import multiclass_classification, plot_feature_importance_plot_using_rf
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
configs = load_config(os.path.join("configs", "configs.yaml"))

# %% [markdown]
# ## 1. Prepare data from first study

# %% [markdown]
# #### 1.1 Reproduce the same steps as notebooks from colorectal_adenocarcinoma/colorectal_multiclass.ipynb
#
# Note: OS_MONTHS instead of PFS_MONTHS is used for target column in this analysis since its available in both studies and seem to be used by many research projects.

# %%
# load patient data
patientdf = pd.read_csv(
    os.path.join(configs["STORAGE_DIR_STUDY2"], "data_clinical_patient.txt"),
    sep="\t",
    header=4
)

columns_being_discarded =  [
    # 'SUBTYPE', # consider for later analysis
    'CANCER_TYPE_ACRONYM', # same value for all records
    'OTHER_PATIENT_ID', # id column not related to any data of our interest
    'AJCC_STAGING_EDITION', # version of handbook used for classification
    'DAYS_LAST_FOLLOWUP', # similar but more relevant information captured in OS_Months
    'DAYS_TO_BIRTH', # age captures similar information 
    'DAYS_TO_INITIAL_PATHOLOGIC_DIAGNOSIS', # similar but more relevant information captured in OS_Months 
    'ETHNICITY', # race column has more rich data
    'FORM_COMPLETION_DATE', # irrelevant to analysis
    'HISTORY_NEOADJUVANT_TRTYN', # highly skewed, 590 No, 2 Yes, 2 Null
    'ICD_O_3_HISTOLOGY' , # which edition of certain code used for tabulating data
    'ICD_O_3_SITE', # which edition of certain code used for tabulating data
    'INFORMED_CONSENT_VERIFIED', # irrelevant to analysis
    'PRIMARY_LYMPH_NODE_PRESENTATION_ASSESSMENT', # highly skewed 557 Yes, 19 No, 18 Null
    'IN_PANCANPATHWAYS_FREEZE', # if patient is part of a certain analysis, irrelevant
    ]

patientdf_1 = patientdf.drop(columns=columns_being_discarded)

# load sample data
sampledf = pd.read_csv(
    os.path.join(configs["STORAGE_DIR_STUDY2"], "data_clinical_sample.txt"),
    sep="\t",
    header=4
)

columns_being_discarded_sampledf = [
    'TISSUE_PROSPECTIVE_COLLECTION_INDICATOR', # when sample was collected, before or after
    'TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR', # when sample was collected, before or after
    'TISSUE_SOURCE_SITE_CODE', # which hospital was the sample collected at
    'TUMOR_TISSUE_SITE', # part of body where sample was collected
    'SAMPLE_TYPE', # has only one value "Primary"
    'TISSUE_SOURCE_SITE' # which hospital was the sample collected at
]

sampledf_1 = sampledf.drop(columns=columns_being_discarded_sampledf)

# merge patient and sample 
merge_df = pd.merge(patientdf_1, sampledf_1, on='PATIENT_ID', how='inner')

# drop columns based on analysis done in the reference notebook
columns_to_drop = [
    'GRADE',
    'DFS_MONTHS', 'DFS_STATUS',
    'SUBTYPE', 'ICD_10',
    'NEW_TUMOR_EVENT_AFTER_INITIAL_TREATMENT',
    'DSS_STATUS', 'DSS_MONTHS',
    # 'AJCC_PATHOLOGIC_TUMOR_STAGE', not removing for now since new dataset has many values for column
    'SOMATIC_STATUS',
    'TUMOR_TYPE',
    'CANCER_TYPE',
    'RACE',
    'CANCER_TYPE_DETAILED'
]

df = merge_df.drop(columns=columns_to_drop)

# drop any row with missing value
df1 = df.dropna()

# keep only cases with recurrence
df1 = df1[df1["PFS_STATUS"] == "1:PROGRESSION"]
df1.drop(["PFS_STATUS"], axis=1, inplace=True)

# filter out rows with missing value for race since we plan to merge data with other dataset, so trying to retain high-quality data only.
df1 = df1[df1.GENETIC_ANCESTRY_LABEL != " "]

# save results for merging later
df1.to_csv(
    os.path.join(
        configs["STORAGE_DIR_STUDY2"], "recurrence_clinical.csv"),
    index=False
    )

study1_df1 = df1.copy()

# %% [markdown]
# Steps before passing into the model
# 1. pass it thru preprocess_data function.
# 2. separate out y.

# %% [markdown]
# ##### Data Specifications for the pipeline:
# 1. GENETIC_ANCESTRY_LABEL:
#     - has values like [' ', 'AFR', 'AFR_ADMIX', 'EAS', 'EUR', 'EUR_ADMIX']
#     - highly skewed toward EUR.
#     - output 1 for EUR(white), 0 for non-EUR(non-white).
#     - potentially modify later to include other races if good number of records are available.
#
# 1. PRIOR_DX
#     - starts with either Yes or No.
#
# 1. PATH_M_STAGE
#     - contains values out of [M0, M1, M1A, M1B, MX]
#
# 1. PATH_T_STAGE
#     - contains values out of ['T1', 'T2', 'T3', 'T4', 'T4A', 'T4B', 'TIS']
#
# 1. PATH_N_STAGE
#     - contains values out of ['N0', 'N1', 'N1A', 'N1B', 'N1C', 'N2', 'N2A', 'N2B']
#
# 1. All other columns are either object type or int64 type.

# %%
print("Column in Study 2:")
for column in sorted(df1.columns):
    print(column)
# Out:
# Column in Study 2:
# AGE
# AJCC_PATHOLOGIC_TUMOR_STAGE
# ANEUPLOIDY_SCORE
# GENETIC_ANCESTRY_LABEL
# MSI_SCORE_MANTIS
# MSI_SENSOR_SCORE
# ONCOTREE_CODE
# PATH_M_STAGE
# PATH_N_STAGE
# PATH_T_STAGE
# PATIENT_ID
# PERSON_NEOPLASM_CANCER_STATUS
# PFS_MONTHS
# PRIOR_DX
# RADIATION_THERAPY
# SAMPLE_ID
# SEX
# TMB_NONSYNONYMOUS
# WEIGHT

# %% [markdown]
# Used study2/user_friendly_formats/recurrence_clinical_edited.xlsx for matching column name to column definitions

# %%
pd.read_excel(
    os.path.join(configs["STORAGE_DIR_STUDY2"], "user_friendly_formats", "recurrence_clinical_edited.xlsx"),
    sheet_name="Used_Column_Defintions"
)
# Out:
#                        PATIENT_ID  \
# 0                             AGE
# 1                             SEX
# 2                    PATH_M_STAGE
# 3                    PATH_N_STAGE
# 4                    PATH_T_STAGE
# 5   PERSON_NEOPLASM_CANCER_STATUS
# 6                        PRIOR_DX
# 7               RADIATION_THERAPY
# 8                          WEIGHT
# 9                      PFS_MONTHS
# 10         GENETIC_ANCESTRY_LABEL
# 11                      SAMPLE_ID
# 12                  ONCOTREE_CODE
# 13               ANEUPLOIDY_SCORE
# 14               MSI_SCORE_MANTIS
# 15               MSI_SENSOR_SCORE
# 16              TMB_NONSYNONYMOUS
#
#                                   #Patient Identifier
# 0                                       Diagnosis Age
# 1                                                 Sex
# 2   American Joint Committee on Cancer Metastasis ...
# 3   Neoplasm Disease Lymph Node Stage American Joi...
# 4   American Joint Committee on Cancer Tumor Stage...
# 5                       Person Neoplasm Cancer Status
# 6                                     Prior Diagnosis
# 7                                   Radiation Therapy
# 8                                      Patient Weight
# 9                     Progress Free Survival (Months)
# 10                             Genetic Ancestry Label
# 11                                  Sample Identifier
# 12                                      Oncotree Code
# 13                                   Aneuploidy Score
# 14                                   MSI MANTIS Score
# 15                                    MSIsensor Score
# 16                                TMB (nonsynonymous)

# %% [markdown]
# ## 2. Clean data from second study

# %% [markdown]
# #### 2.1 Join Patient and Sample data and analyze

# %%
patientdf = pd.read_csv(
    os.path.join(configs["STORAGE_DIR_STUDY3"], "data_clinical_patient.txt"),
    sep="\t"
    # header=4
)
patientdf.head()

patientdf.to_excel(
    os.path.join(configs["STORAGE_DIR_STUDY3"], "user_friendly_formats", "patientdf.xlsx"),
    index=False)

# %%
# load sample data
sampledf = pd.read_csv(
    os.path.join(configs["STORAGE_DIR_STUDY3"], "data_clinical_sample.txt"),
    sep="\t"
    # header=4
)

sampledf.to_excel(
    os.path.join(configs["STORAGE_DIR_STUDY3"], "user_friendly_formats", "sampledf.xlsx"),
    index=False)

# %% [markdown]
# Analyzed data in excel using study3/user_friendly_formats/patientdf_edited and enlisted columns that are not needed since they donot have a match in study 1.

# %%
patientdf = pd.read_csv(
    os.path.join(configs["STORAGE_DIR_STUDY3"], "data_clinical_patient.txt"),
    sep="\t",
    header=4
)
sampledf = pd.read_csv(
    os.path.join(configs["STORAGE_DIR_STUDY3"], "data_clinical_sample.txt"),
    sep="\t",
    header=4
)

merge_df = pd.merge(patientdf, sampledf, on='PATIENT_ID', how='inner')
merge_df.shape
# Out:
# (633, 86)

# %% [markdown]
# #### 2.2 Remove useless columns

# %%
columns_to_drop = [
    "OTHER_PATIENT_ID",
    "FORM_COMPLETION_DATE",
    "HISTOLOGICAL_DIAGNOSIS",
    "PROSPECTIVE_COLLECTION",
    "RETROSPECTIVE_COLLECTION",
    "ETHNICITY",
    "HISTORY_NEOADJUVANT_TRTYN",
    "INITIAL_PATHOLOGIC_DX_YEAR",
    "AJCC_STAGING_EDITION",
    "RESIDUAL_TUMOR",
    "LYMPH_NODES_EXAMINED",
    "LYMPH_NODE_EXAMINED_COUNT",
    "LYMPH_NODES_EXAMINED_HE_COUNT",
    "LYMPH_NODES_EXAMINED_IHC_COUNT",
    "VASCULAR_INVASION_INDICATOR",
    "LYMPHOVASCULAR_INVASION_INDICATOR",
    "PERINEURAL_INVASION",
    "KRAS_GENE_ANALYSIS_INDICATOR",
    "KRAS_MUTATION",
    "BRAF_GENE_ANALYSIS_INDICATOR",
    "BRAF_GENE_ANALYSIS_RESULT",
    "HEIGHT",
    "RADIATION_TREATMENT_ADJUVANT",
    "PHARMACEUTICAL_TX_ADJUVANT",
    "TREATMENT_OUTCOME_FIRST_COURSE",
    "NEW_TUMOR_EVENT_AFTER_INITIAL_TREATMENT",
    "PRIMARY_SITE_PATIENT",
    "CLIN_M_STAGE",
    "CLIN_N_STAGE",
    "CLIN_T_STAGE",
    "CLINICAL_STAGE",
    "DAYS_TO_INITIAL_PATHOLOGIC_DIAGNOSIS",
    "DAYS_TO_PATIENT_PROGRESSION_FREE",
    "DAYS_TO_TUMOR_PROGRESSION",
    "DISEASE_CODE",
    "EXTRANODAL_INVOLVEMENT",
    "ICD_10",
    "ICD_O_3_HISTOLOGY",
    "ICD_O_3_SITE",
    "INFORMED_CONSENT_VERIFIED",
    "INITIAL_PATHOLOGIC_DIAGNOSIS_METHOD",
    "PROJECT_CODE",
    "STAGE_OTHER",
    "TISSUE_SOURCE_SITE_x",
    "TISSUE_SOURCE_SITE_y",
    "SITE_OF_TUMOR_TISSUE",
    "CANCER_TYPE",
    "CANCER_TYPE_DETAILED",
    "TUMOR_TYPE",
    "GRADE",
    "TISSUE_PROSPECTIVE_COLLECTION_INDICATOR",
    "TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR",
    "TISSUE_SOURCE_SITE_CODE",
    "TUMOR_TISSUE_SITE",
    "SAMPLE_TYPE",
    "SOMATIC_STATUS",
    "OS_MONTHS", 
    "OS_STATUS"
]

# %%
df = merge_df.drop(columns=columns_to_drop, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df = merge_df.drop(columns=columns_to_drop, axis=1)
#
# File /opt/anaconda3/envs/cancer_project1/lib/python3.12/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File /opt/anaconda3/envs/cancer_project1/lib/python3.12/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File /opt/anaconda3/envs/cancer_project1/lib/python3.12/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File /opt/anaconda3/envs/cancer_project1/lib/python3.12/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['TISSUE_SOURCE_SITE_x', 'TISSUE_SOURCE_SITE_y', 'TUMOR_TYPE', 'GRADE', 'TISSUE_PROSPECTIVE_COLLECTION_INDICATOR', 'TISSUE_RETROSPECTIVE_COLLECTION_INDICATOR', 'TISSUE_SOURCE_SITE_CODE', 'TUMOR_TISSUE_SITE'] not found in axis"

# %% [markdown]
# #### 2.3 Match columns in both tables and join

# %%
df = df.rename(columns=
               {
                    "AJCC_METASTASIS_PATHOLOGIC_PM": "PATH_M_STAGE",
                    "AJCC_NODES_PATHOLOGIC_PN": "PATH_N_STAGE",
                    "AJCC_TUMOR_PATHOLOGIC_PT": "PATH_T_STAGE",
                    "DFS_MONTHS": "PFS_MONTHS",
                    "DFS_STATUS": "PFS_STATUS",
                    "HISTORY_OTHER_MALIGNANCY": "PRIOR_DX"
                })

# %%
# datatype corrections:
df["PFS_MONTHS"].replace('[Not Available]', None, inplace=True)
df['PFS_MONTHS'] = pd.to_numeric(df['PFS_MONTHS'])

# %%
df["WEIGHT"].replace('[Not Available]', None, inplace=True)

df['WEIGHT'] = pd.to_numeric(df['WEIGHT'])

# %%
df1 = df[df["PFS_STATUS"] == "1:Recurred/Progressed"]
df1 = df1.drop(["PFS_STATUS"], axis=1)
df.shape, df1.shape
# Out:
# ((591, 19), (111, 18))

# %%
study2_df1 = df1.copy()

# %%
show_unique_vals_by_column(study2_df1)
# Out:
# Column 'AJCC_PATHOLOGIC_TUMOR_STAGE' has 12 unique values: ['Stage I', 'Stage II', 'Stage IIA', 'Stage IIB', 'Stage III', 'Stage IIIA', 'Stage IIIB', 'Stage IIIC', 'Stage IV', 'Stage IVA'] ...
# Column 'ONCOTREE_CODE' has 3 unique values: ['COAD', 'MACR', 'READ']
# Column 'PATH_M_STAGE' has 6 unique values: ['M0', 'M1', 'M1a', 'M1b', 'MX', '[Not Available]']
# Column 'PATH_N_STAGE' has 7 unique values: ['N0', 'N1', 'N1a', 'N1b', 'N2', 'N2a', 'N2b']
# Column 'PATH_T_STAGE' has 6 unique values: ['T1', 'T2', 'T3', 'T4', 'T4a', 'T4b']
# Column 'PATIENT_ID' has 122 unique values: ['TCGA-5M-AAT4', 'TCGA-5M-AAT6', 'TCGA-A6-2671', 'TCGA-A6-2676', 'TCGA-A6-2677', 'TCGA-A6-2682', 'TCGA-A6-2683', 'TCGA-A6-2686', 'TCGA-A6-4105', 'TCGA-A6-A565'] ...
# Column 'PRIOR_DX' has 2 unique values: ['No', 'Yes']
# Column 'RACE' has 4 unique values: ['ASIAN', 'BLACK OR AFRICAN AMERICAN', 'WHITE', '[Not Available]']
# Column 'SAMPLE_ID' has 122 unique values: ['TCGA-5M-AAT4-01', 'TCGA-5M-AAT6-01', 'TCGA-A6-2671-01', 'TCGA-A6-2676-01', 'TCGA-A6-2677-01', 'TCGA-A6-2682-01', 'TCGA-A6-2683-01', 'TCGA-A6-2686-01', 'TCGA-A6-4105-01', 'TCGA-A6-A565-01'] ...
# Column 'SEX' has 2 unique values: ['Female', 'Male']
# Column 'TUMOR_STATUS' has 4 unique values: ['TUMOR FREE', 'WITH TUMOR', '[Discrepancy]', '[Not Available]']
# Ignored these numeric columns: ['AGE', 'ANEUPLOIDY_SCORE', 'MSI_SCORE_MANTIS', 'MSI_SENSOR_SCORE', 'PFS_MONTHS', 'TMB_NONSYNONYMOUS', 'WEIGHT']

# %% [markdown]
# Columns with missing values:
# 1. RACE: [Not Available]
# 2. TUMOR_STATUS: '[Discrepancy]', '[Not Available]'

# %%
study1_df1.RADIATION_THERAPY.value_counts()
# Out:
# RADIATION_THERAPY
# No     56
# Yes     4
# Name: count, dtype: int64

# %% [markdown]
# RADIATION_THERAPY has very skewed values and is not present in second study, so removing it.

# %%
study1_df1 = study1_df1.drop("RADIATION_THERAPY", axis=1)

study1_df1 = study1_df1.rename(columns={
    "PERSON_NEOPLASM_CANCER_STATUS": "TUMOR_STATUS",
    "GENETIC_ANCESTRY_LABEL": "RACE"
})

# %%
show_unique_vals_by_column(study1_df1)
# Out:
# Column 'AJCC_PATHOLOGIC_TUMOR_STAGE' has 9 unique values: ['STAGE I', 'STAGE IIA', 'STAGE IIB', 'STAGE IIC', 'STAGE IIIB', 'STAGE IIIC', 'STAGE IV', 'STAGE IVA', 'STAGE IVB']
# Column 'ONCOTREE_CODE' has 3 unique values: ['COAD', 'MACR', 'READ']
# Column 'PATH_M_STAGE' has 5 unique values: ['M0', 'M1', 'M1A', 'M1B', 'MX']
# Column 'PATH_N_STAGE' has 8 unique values: ['N0', 'N1', 'N1A', 'N1B', 'N1C', 'N2', 'N2A', 'N2B']
# Column 'PATH_T_STAGE' has 5 unique values: ['T2', 'T3', 'T4', 'T4A', 'T4B']
# Column 'PATIENT_ID' has 60 unique values: ['TCGA-5M-AAT6', 'TCGA-A6-2671', 'TCGA-A6-2674', 'TCGA-A6-2681', 'TCGA-A6-2683', 'TCGA-A6-2684', 'TCGA-A6-2685', 'TCGA-A6-4105', 'TCGA-A6-5664', 'TCGA-A6-5665'] ...
# Column 'PRIOR_DX' has 2 unique values: ['No', 'Yes']
# Column 'RACE' has 4 unique values: ['AFR', 'AFR_ADMIX', 'EAS', 'EUR']
# Column 'SAMPLE_ID' has 60 unique values: ['TCGA-5M-AAT6-01', 'TCGA-A6-2671-01', 'TCGA-A6-2674-01', 'TCGA-A6-2681-01', 'TCGA-A6-2683-01', 'TCGA-A6-2684-01', 'TCGA-A6-2685-01', 'TCGA-A6-4105-01', 'TCGA-A6-5664-01', 'TCGA-A6-5665-01'] ...
# Column 'SEX' has 2 unique values: ['Female', 'Male']
# Column 'TUMOR_STATUS' has 2 unique values: ['Tumor Free', 'With Tumor']
# Ignored these numeric columns: ['AGE', 'ANEUPLOIDY_SCORE', 'MSI_SCORE_MANTIS', 'MSI_SENSOR_SCORE', 'PFS_MONTHS', 'TMB_NONSYNONYMOUS', 'WEIGHT']

# %%
# ensuring both studies have same columns
for column in study1_df1.columns:
    if column not in study2_df1:
        print(column)

for column in study2_df1.columns:
    if column not in study1_df1:
        print(column)

# %%
study1_df1["STUDY_NAME"] = "STUDY1"
study2_df1["STUDY_NAME"] = "STUDY2"

# %%
df = pd.concat([study1_df1, study2_df1], axis=0)
df.shape
# Out:
# (182, 19)

# %%
has_duplicates = df['PATIENT_ID'].duplicated().any()
print(f"Column 'PATIENT_ID' has duplicates: {has_duplicates}")

df["PATIENT_ID"].value_counts().sort_values(ascending=False)

repeating_values_rows = df[df['PATIENT_ID'].duplicated(keep=False)]

# Display the rows
print("Rows with repeating values in column 'PATIENT_ID':")
repeating_values_rows.sort_values(by="PATIENT_ID")
# Out:
# Column 'PATIENT_ID' has duplicates: True
# Rows with repeating values in column 'PATIENT_ID':
#        PATIENT_ID   AGE     SEX AJCC_PATHOLOGIC_TUMOR_STAGE PATH_M_STAGE  \
# 4    TCGA-5M-AAT6  40.0  Female                    STAGE IV          M1A
# 5    TCGA-5M-AAT6  40.0  Female                    Stage IV          M1a
# 7    TCGA-A6-2671  85.0    Male                    Stage IV           M1
# 6    TCGA-A6-2671  85.0    Male                    STAGE IV           M1
# 18   TCGA-A6-2683  57.0  Female                    Stage IV           M1
# 17   TCGA-A6-2683  57.0  Female                    STAGE IV           M1
# 26   TCGA-A6-4105  79.0    Male                   Stage IIA           M0
# 25   TCGA-A6-4105  79.0    Male                   STAGE IIA           M0
# 53   TCGA-A6-A565  34.0  Female                  Stage IIIC           MX
# 52   TCGA-A6-A565  34.0  Female                  STAGE IIIC           MX
# 53   TCGA-A6-A566  55.0  Female                  STAGE IIIB           M0
# 54   TCGA-A6-A566  55.0  Female                  Stage IIIB           M0
# 55   TCGA-A6-A567  56.0    Male                    Stage IV           M1
# 54   TCGA-A6-A567  56.0    Male                    STAGE IV           M1
# 56   TCGA-A6-A56B  57.0    Male                  Stage IIIB           M0
# 55   TCGA-A6-A56B  57.0    Male                  STAGE IIIB           M0
# 217  TCGA-AD-6888  73.0    Male                  STAGE IIIB           M0
# 218  TCGA-AD-6888  73.0    Male                  Stage IIIB           M0
# 438  TCGA-AF-2689  41.0  Female                    Stage IV           M1
# 440  TCGA-AF-2689  41.0  Female                    STAGE IV           M1
# 233  TCGA-AY-4070  50.0  Female                  Stage IIIC           M0
# 232  TCGA-AY-4070  50.0  Female                  STAGE IIIC           M0
# 247  TCGA-AZ-4614  71.0  Female                   Stage IVA           M1
# 246  TCGA-AZ-4614  71.0  Female                   STAGE IVA           M1
# 250  TCGA-AZ-4682  61.0    Male                   STAGE IVA           M1
# 251  TCGA-AZ-4682  61.0    Male                   Stage IVA           M1
# 269  TCGA-CA-6718  46.0    Male                   STAGE IIA           M0
# 270  TCGA-CA-6718  46.0    Male                   Stage IIA           M0
# 300  TCGA-CM-5862  80.0    Male                   Stage IVA          M1a
# 299  TCGA-CM-5862  80.0    Male                   STAGE IVA          M1A
# 322  TCGA-D5-5537  83.0    Male                   STAGE IIA           MX
# 323  TCGA-D5-5537  83.0    Male               [Discrepancy]           MX
# 324  TCGA-D5-5538  60.0  Female                  Stage IIIB           M0
# 323  TCGA-D5-5538  60.0  Female                  STAGE IIIB           M0
# 336  TCGA-D5-6537  64.0    Male                  Stage IIIB           MX
# 335  TCGA-D5-6537  64.0    Male                  STAGE IIIB           MX
# 381  TCGA-F4-6461  41.0  Female                  Stage IIIC           M0
# 380  TCGA-F4-6461  41.0  Female                  STAGE IIIC           M0
# 390  TCGA-F4-6809  52.0  Female                   STAGE IVA           M1
# 391  TCGA-F4-6809  52.0  Female                   Stage IVA           M1
# 584  TCGA-F5-6702  71.0    Male                   STAGE IVA           M1
# 582  TCGA-F5-6702  71.0    Male                   Stage IVA           M1
# 395  TCGA-G4-6294  75.0    Male                    STAGE IV           M1
# 396  TCGA-G4-6294  75.0    Male                    Stage IV           M1
# 398  TCGA-G4-6298  90.0    Male                  STAGE IIIB           MX
# 399  TCGA-G4-6298  90.0    Male                  Stage IIIB           MX
# 401  TCGA-G4-6303  54.0  Female                    STAGE IV           M1
# 402  TCGA-G4-6303  54.0  Female                    Stage IV           M1
# 419  TCGA-NH-A50U  42.0    Male                   STAGE IVA          M1A
# 420  TCGA-NH-A50U  42.0    Male                   Stage IVA          M1a
# 423  TCGA-NH-A6GA  58.0    Male                  Stage IIIC           MX
# 422  TCGA-NH-A6GA  58.0    Male                  STAGE IIIC           MX
#
#     PATH_N_STAGE PATH_T_STAGE TUMOR_STATUS PRIOR_DX  WEIGHT  PFS_MONTHS  \
# 4            N2B          T4A   With Tumor       No    99.1    7.199921
# 5            N2b          T4a   WITH TUMOR       No    99.1    9.530000
# 7             N2           T3   WITH TUMOR       No    67.2   43.730000
# 6             N2           T3   With Tumor       No    67.2   17.588848
# 18            N0           T4   WITH TUMOR       No    57.5   16.560000
# 17            N0           T4   With Tumor       No    57.5    9.862906
# 26            N0           T3   TUMOR FREE      Yes    83.3   14.520000
# 25            N0           T3   Tumor Free      Yes    83.3   11.966992
# 53            N2           T3   WITH TUMOR       No    66.7   16.230000
# 52            N2           T3   With Tumor       No    66.7    9.895782
# 53            N1           T4   With Tumor       No    66.1    8.449222
# 54            N1           T4   WITH TUMOR       No    66.1   24.900000
# 55            N1           T3   WITH TUMOR       No    84.0   61.790000
# 54            N1           T3   With Tumor       No    84.0   20.120327
# 56            N1           T3   TUMOR FREE       No    77.2   56.210000
# 55            N1           T3   Tumor Free       No    77.2   55.166519
# 217          N1B           T3   Tumor Free      Yes    96.0   11.276589
# 218          N1b           T3   TUMOR FREE      Yes    96.0   15.510000
# 438           N2           T3   WITH TUMOR       No    55.5   39.450000
# 440           N2           T3   With Tumor       No    55.5    9.895782
# 233           N2           T3   WITH TUMOR       No   100.8   16.290000
# 232           N2           T3   With Tumor       No   100.8    6.115001
# 247           N1          T4a   WITH TUMOR       No    70.0    5.650000
# 246           N1          T4A   With Tumor       No    70.0    5.654733
# 250           N0           T3   With Tumor       No    98.0   22.355919
# 251           N0           T3   WITH TUMOR       No    98.0   22.340000
# 269           N0           T3   Tumor Free       No    63.0    6.805405
# 270           N0           T3   TUMOR FREE       No    63.0   10.050000
# 300          N1a           T3   WITH TUMOR       No    77.6    5.030000
# 299          N1A           T3   With Tumor       No    77.6    1.019167
# 322           N2           T3   Tumor Free       No    75.0   23.736726
# 323           N2           T3   TUMOR FREE       No    75.0   45.370000
# 324          N1b           T3   TUMOR FREE       No    70.0   54.570000
# 323          N1B           T3   Tumor Free       No    70.0   33.106487
# 336          N1a           T3   TUMOR FREE       No    80.0    4.800000
# 335          N1A           T3   Tumor Free       No    80.0    4.043791
# 381           N2          T4b   TUMOR FREE       No    57.0   11.100000
# 380           N2          T4B   Tumor Free       No    57.0    9.468389
# 390           N1           T3   With Tumor       No    88.0   13.249170
# 391           N1           T3   WITH TUMOR       No    88.0   13.240000
# 584           N1           T3   With Tumor       No    76.0   12.098498
# 582           N1           T3   WITH TUMOR       No    76.0   28.550000
# 395           N1           T3   With Tumor      Yes    47.5   16.997074
# 396           N1           T3   WITH TUMOR      Yes    47.5   28.190000
# 398           N1          T4A   With Tumor      Yes    59.4    9.567018
# 399           N1          T4a   WITH TUMOR      Yes    59.4   23.490000
# 401           N1           T3   With Tumor       No    69.0   28.668179
# 402           N1           T3   WITH TUMOR       No    69.0   65.800000
# 419           N0          T4A   With Tumor       No    88.5    9.073873
# 420           N0          T4a   WITH TUMOR       No    88.5   10.970000
# 423          N2a          T4a   WITH TUMOR       No    92.0    9.920000
# 422          N2A          T4A   With Tumor       No    92.0    0.197258
#
#                           RACE        SAMPLE_ID ONCOTREE_CODE  \
# 4                          AFR  TCGA-5M-AAT6-01          COAD
# 5    BLACK OR AFRICAN AMERICAN  TCGA-5M-AAT6-01          COAD
# 7                        WHITE  TCGA-A6-2671-01          COAD
# 6                          EUR  TCGA-A6-2671-01          COAD
# 18                       WHITE  TCGA-A6-2683-01          COAD
# 17                         EUR  TCGA-A6-2683-01          COAD
# 26                       WHITE  TCGA-A6-4105-01          COAD
# 25                         EUR  TCGA-A6-4105-01          COAD
# 53   BLACK OR AFRICAN AMERICAN  TCGA-A6-A565-01          MACR
# 52                         AFR  TCGA-A6-A565-01          MACR
# 53                         AFR  TCGA-A6-A566-01          MACR
# 54   BLACK OR AFRICAN AMERICAN  TCGA-A6-A566-01          MACR
# 55   BLACK OR AFRICAN AMERICAN  TCGA-A6-A567-01          COAD
# 54                         AFR  TCGA-A6-A567-01          COAD
# 56   BLACK OR AFRICAN AMERICAN  TCGA-A6-A56B-01          COAD
# 55                         AFR  TCGA-A6-A56B-01          COAD
# 217                        EUR  TCGA-AD-6888-01          COAD
# 218                      WHITE  TCGA-AD-6888-01          COAD
# 438                      WHITE  TCGA-AF-2689-01          READ
# 440                        EUR  TCGA-AF-2689-01          READ
# 233  BLACK OR AFRICAN AMERICAN  TCGA-AY-4070-01          COAD
# 232                        AFR  TCGA-AY-4070-01          COAD
# 247                      WHITE  TCGA-AZ-4614-01          COAD
# 246                        EUR  TCGA-AZ-4614-01          COAD
# 250                        EUR  TCGA-AZ-4682-01          COAD
# 251                      WHITE  TCGA-AZ-4682-01          COAD
# 269                        EAS  TCGA-CA-6718-01          COAD
# 270                      ASIAN  TCGA-CA-6718-01          COAD
# 300                      WHITE  TCGA-CM-5862-01          COAD
# 299                        EUR  TCGA-CM-5862-01          COAD
# 322                        EUR  TCGA-D5-5537-01          COAD
# 323                      WHITE  TCGA-D5-5537-01          COAD
# 324                      WHITE  TCGA-D5-5538-01          COAD
# 323                        EUR  TCGA-D5-5538-01          COAD
# 336                      WHITE  TCGA-D5-6537-01          COAD
# 335                        EUR  TCGA-D5-6537-01          COAD
# 381                      WHITE  TCGA-F4-6461-01          COAD
# 380                        EUR  TCGA-F4-6461-01          COAD
# 390                        EUR  TCGA-F4-6809-01          COAD
# 391                      WHITE  TCGA-F4-6809-01          COAD
# 584                        EUR  TCGA-F5-6702-01          READ
# 582                      WHITE  TCGA-F5-6702-01          READ
# 395                        EUR  TCGA-G4-6294-01          COAD
# 396                      WHITE  TCGA-G4-6294-01          COAD
# 398                        AFR  TCGA-G4-6298-01          COAD
# 399  BLACK OR AFRICAN AMERICAN  TCGA-G4-6298-01          COAD
# 401                        EUR  TCGA-G4-6303-01          COAD
# 402                      WHITE  TCGA-G4-6303-01          COAD
# 419                        AFR  TCGA-NH-A50U-01          MACR
# 420  BLACK OR AFRICAN AMERICAN  TCGA-NH-A50U-01          MACR
# 423  BLACK OR AFRICAN AMERICAN  TCGA-NH-A6GA-01          COAD
# 422                        AFR  TCGA-NH-A6GA-01          COAD
#
#      ANEUPLOIDY_SCORE  MSI_SCORE_MANTIS  MSI_SENSOR_SCORE  TMB_NONSYNONYMOUS  \
# 4                 3.0            0.6600             20.58          62.166667
# 5                 3.0            0.6600             20.58          62.166667
# 7                25.0            0.3500              0.37           4.066667
# 6                25.0            0.3500              0.37           4.066667
# 18               20.0            0.3644              1.46           2.133333
# 17               20.0            0.3644              1.46           2.133333
# 26               17.0            0.3528              0.30           4.866667
# 25               17.0            0.3528              0.30           4.866667
# 53                0.0            0.3972              0.41          12.200000
# 52                0.0            0.3972              0.41          12.200000
# 53                4.0            0.2956              0.00           5.133333
# 54                4.0            0.2956              0.00           5.133333
# 55               14.0            0.2929              0.07           1.700000
# 54               14.0            0.2929              0.07           1.700000
# 56               11.0            0.3073              0.22           2.800000
# 55               11.0            0.3073              0.22           2.800000
# 217              30.0            0.3466              0.13           3.500000
# 218              30.0            0.3466              0.13           3.500000
# 438              18.0            0.3486              1.28           1.733333
# 440              18.0            0.3486              1.28           1.733333
# 233              18.0            0.2687              0.78           5.033333
# 232              18.0            0.2687              0.78           5.033333
# 247               7.0            0.3773              0.94           6.000000
# 246               7.0            0.3773              0.94           6.000000
# 250              10.0            0.3670              0.13           2.366667
# 251              10.0            0.3670              0.13           2.366667
# 269               2.0            0.3722              0.00         107.066667
# 270               2.0            0.3722              0.00         107.066667
# 300              26.0            0.3545              1.45           2.866667
# 299              26.0            0.3545              1.45           2.866667
# 322              19.0            0.3494              0.42           3.166667
# 323              19.0            0.3494              0.42           3.166667
# 324               7.0            0.3546              0.40           3.500000
# 323               7.0            0.3546              0.40           3.500000
# 336              12.0            0.3503              0.37           3.400000
# 335              12.0            0.3503              0.37           3.400000
# 381               1.0            0.3699              0.23           4.600000
# 380               1.0            0.3699              0.23           4.600000
# 390               8.0            0.3476              0.02           5.033333
# 391               8.0            0.3476              0.02           5.033333
# 584              28.0            0.3280              0.02           2.100000
# 582              28.0            0.3280              0.02           2.100000
# 395               7.0            0.3774              1.01           5.033333
# 396               7.0            0.3774              1.01           5.033333
# 398              13.0            0.3334              0.31           5.266667
# 399              13.0            0.3334              0.31           5.266667
# 401              17.0            0.3590              0.50           2.833333
# 402              17.0            0.3590              0.50           2.833333
# 419              23.0            0.3425              0.50           2.900000
# 420              23.0            0.3425              0.50           2.900000
# 423              13.0            0.3295              1.07           2.833333
# 422              13.0            0.3295              1.07           2.833333
#
#     STUDY_NAME
# 4       STUDY1
# 5       STUDY2
# 7       STUDY2
# 6       STUDY1
# 18      STUDY2
# 17      STUDY1
# 26      STUDY2
# 25      STUDY1
# 53      STUDY2
# 52      STUDY1
# 53      STUDY1
# 54      STUDY2
# 55      STUDY2
# 54      STUDY1
# 56      STUDY2
# 55      STUDY1
# 217     STUDY1
# 218     STUDY2
# 438     STUDY2
# 440     STUDY1
# 233     STUDY2
# 232     STUDY1
# 247     STUDY2
# 246     STUDY1
# 250     STUDY1
# 251     STUDY2
# 269     STUDY1
# 270     STUDY2
# 300     STUDY2
# 299     STUDY1
# 322     STUDY1
# 323     STUDY2
# 324     STUDY2
# 323     STUDY1
# 336     STUDY2
# 335     STUDY1
# 381     STUDY2
# 380     STUDY1
# 390     STUDY1
# 391     STUDY2
# 584     STUDY1
# 582     STUDY2
# 395     STUDY1
# 396     STUDY2
# 398     STUDY1
# 399     STUDY2
# 401     STUDY1
# 402     STUDY2
# 419     STUDY1
# 420     STUDY2
# 423     STUDY2
# 422     STUDY1

# %% [markdown]
# ## 3. Prepare X using merged table

# %% [markdown]
# #### 3.1 Find columns needing more cleanup

# %%
show_unique_vals_by_column(df.drop(["PATIENT_ID", "SAMPLE_ID"], axis=1))
# Out:
# Column 'AJCC_PATHOLOGIC_TUMOR_STAGE' has 21 unique values: ['STAGE I', 'STAGE IIA', 'STAGE IIB', 'STAGE IIC', 'STAGE IIIB', 'STAGE IIIC', 'STAGE IV', 'STAGE IVA', 'STAGE IVB', 'Stage I'] ...
# Column 'ONCOTREE_CODE' has 3 unique values: ['COAD', 'MACR', 'READ']
# Column 'PATH_M_STAGE' has 8 unique values: ['M0', 'M1', 'M1A', 'M1B', 'M1a', 'M1b', 'MX', '[Not Available]']
# Column 'PATH_N_STAGE' has 12 unique values: ['N0', 'N1', 'N1A', 'N1B', 'N1C', 'N1a', 'N1b', 'N2', 'N2A', 'N2B'] ...
# Column 'PATH_T_STAGE' has 8 unique values: ['T1', 'T2', 'T3', 'T4', 'T4A', 'T4B', 'T4a', 'T4b']
# Column 'PRIOR_DX' has 2 unique values: ['No', 'Yes']
# Column 'RACE' has 8 unique values: ['AFR', 'AFR_ADMIX', 'ASIAN', 'BLACK OR AFRICAN AMERICAN', 'EAS', 'EUR', 'WHITE', '[Not Available]']
# Column 'SEX' has 2 unique values: ['Female', 'Male']
# Column 'STUDY_NAME' has 2 unique values: ['STUDY1', 'STUDY2']
# Column 'TUMOR_STATUS' has 6 unique values: ['TUMOR FREE', 'Tumor Free', 'WITH TUMOR', 'With Tumor', '[Discrepancy]', '[Not Available]']
# Ignored these numeric columns: ['AGE', 'ANEUPLOIDY_SCORE', 'MSI_SCORE_MANTIS', 'MSI_SENSOR_SCORE', 'PFS_MONTHS', 'TMB_NONSYNONYMOUS', 'WEIGHT']

# %% [markdown]
# Columns needing more cleaning:
# - AJCC_PATHOLOGIC_TUMOR_STAGE
# - PATH_M_STAGE
# - RACE
# - TUMOR_STATUS

# %% [markdown]
# #### 3.2 Clean Tumor Stage

# %%
df["AJCC_PATHOLOGIC_TUMOR_STAGE"].value_counts()
# Out:
# AJCC_PATHOLOGIC_TUMOR_STAGE
# Stage IV           31
# Stage IIA          22
# Stage IIIC         20
# STAGE IIA          13
# Stage IIIB         13
# STAGE IV           11
# STAGE IIIC         10
# STAGE IIIB         10
# STAGE IVA           9
# Stage II            8
# Stage I             7
# Stage IVA           7
# [Not Available]     5
# Stage III           4
# STAGE I             3
# [Discrepancy]       2
# Stage IIB           2
# STAGE IIB           2
# STAGE IVB           1
# STAGE IIC           1
# Stage IIIA          1
# Name: count, dtype: int64

# %%
df["AJCC_PATHOLOGIC_TUMOR_STAGE"] = df["AJCC_PATHOLOGIC_TUMOR_STAGE"].replace(
    '[Not Available]', None
).replace(
    '[Discrepancy]', None
    )

df["AJCC_PATHOLOGIC_TUMOR_STAGE"].value_counts(dropna=False)
# Out:
# AJCC_PATHOLOGIC_TUMOR_STAGE
# Stage IV      31
# Stage IIA     22
# Stage IIIC    20
# STAGE IIA     13
# Stage IIIB    13
# STAGE IV      11
# STAGE IIIC    10
# STAGE IIIB    10
# STAGE IVA      9
# Stage II       8
# Stage IVA      7
# None           7
# Stage I        7
# Stage III      4
# STAGE I        3
# Stage IIB      2
# STAGE IIB      2
# STAGE IVB      1
# STAGE IIC      1
# Stage IIIA     1
# Name: count, dtype: int64

# %% [markdown]
# Note: T Stage and Tumor Stage might be same, check correlation later.

# %% [markdown]
# #### 3.2 Path M Stage

# %%
df["PATH_M_STAGE"].value_counts()
# Out:
# PATH_M_STAGE
# M0                 95
# M1                 47
# MX                 26
# M1A                 6
# M1a                 3
# [Not Available]     3
# M1B                 1
# M1b                 1
# Name: count, dtype: int64

# %%
df["PATH_M_STAGE"] = df["PATH_M_STAGE"].replace(
    '[Not Available]', "MX"
)
df["PATH_M_STAGE"].value_counts()
# Out:
# PATH_M_STAGE
# M0     95
# M1     47
# MX     29
# M1A     6
# M1a     3
# M1B     1
# M1b     1
# Name: count, dtype: int64

# %% [markdown]
# #### 3.3 Race

# %%
df["RACE"].value_counts()
# Out:
# RACE
# WHITE                        69
# EUR                          40
# [Not Available]              38
# AFR                          15
# BLACK OR AFRICAN AMERICAN    13
# AFR_ADMIX                     3
# EAS                           2
# ASIAN                         2
# Name: count, dtype: int64

# %%
print(f"White: {69+40}")
print(f"African: {15+13+3}")
# Out:
# White: 109
# African: 31
