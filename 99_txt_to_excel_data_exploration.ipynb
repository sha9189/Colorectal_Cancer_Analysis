# %%
import pandas as pd
from helpers import load_config
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import numpy as np

config_path = os.path.join("configs", "configs.yaml")
config = load_config(config_path)

# %% [markdown]
# ## Changing raw data files from txt format to xlsx format for better readability

# %%
folder_path = os.path.join(config["STORAGE_DIR_STUDY1"], "user_friendly_formats")
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %% [markdown]
# ### Donot run the code below, excel files generated have been manually edited. Code is commented, so okay to use Run All on this notebook

# %%
# patientdf = pd.read_csv(
#     "Dataset/chol_tcga_pan_can_atlas_2018/data_clinical_patient.txt",
#     sep="\t"
#     # header=4
# )
# patientdf.to_csv(os.path.join(folder_path, "data_clinicial_patient.csv"))
# patientdf.to_excel(os.path.join(folder_path, "data_clinicial_patient.xlsx"))

# %%
# sampledf = pd.read_csv(
#     "Dataset/chol_tcga_pan_can_atlas_2018/data_clinical_sample.txt",
#     sep="\t"
#     # header=4
# )
# sampledf.to_csv(os.path.join(folder_path, "data_clinicial_sample.csv"))
# sampledf.to_excel(os.path.join(folder_path, "data_clinicial_sample.xlsx"))

# %%
patientdf
# Out:
#                            #Patient Identifier  Subtype  \
# 0   #Identifier to uniquely specify a patient.  Subtype
# 1                                      #STRING   STRING
# 2                                           #1        1
# 3                                   PATIENT_ID  SUBTYPE
# 4                                 TCGA-3X-AAV9     CHOL
# 5                                 TCGA-3X-AAVA     CHOL
# 6                                 TCGA-3X-AAVB     CHOL
# 7                                 TCGA-3X-AAVC     CHOL
# 8                                 TCGA-3X-AAVE     CHOL
# 9                                 TCGA-4G-AAZO     CHOL
# 10                                TCGA-4G-AAZT     CHOL
# 11                                TCGA-W5-AA2G     CHOL
# 12                                TCGA-W5-AA2H     CHOL
# 13                                TCGA-W5-AA2I     CHOL
# 14                                TCGA-W5-AA2O     CHOL
# 15                                TCGA-W5-AA2Q     CHOL
# ...
